# %%
import numpy as np
import json
import os

model = 'digits_encoder_redo_squash'
with open(os.path.join('models', model, 'train-history.json'), 'r') as file:
  data = json.load(file)

print(data.keys())
# Out:
# dict_keys(['loss', 'mse', 'cosine_similarity', 'mae', 'val_loss', 'val_mse', 'val_cosine_similarity', 'val_mae', 'lr'])

# %%
import matplotlib.pyplot as plt
i = np.argmin(data['val_loss'])
print(i+1)
print(data['val_mse'][i])
print(data['val_cosine_similarity'][i])
print(len(data['mse']))
print(data['val_mse'][-1])
print(data['val_cosine_similarity'][-1])
e =400
print(e)
print(data['val_mse'][e-1])
print(data['val_cosine_similarity'][e-1])

plt.plot(data['loss'])
plt.plot(data['val_loss'])
plt.show()
# Out:
# 434
# 1.0100840330123901
# 0.2502986192703247
# 600
# 1.013804316520691
# 0.24585933983325958
# 400
# 1.0110533237457275
# 0.24743452668190002
