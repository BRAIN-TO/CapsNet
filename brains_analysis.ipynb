# %%
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt

data_split = loadmat('handwritten_chars_in_fmri_dataset/train_testset.mat') # contains indices used for split
s1v1 = loadmat('handwritten_chars_in_fmri_dataset/sub-01/XS01_V1.mat')
print(s1v1.keys())
print(s1v1['X'].shape) # trials by voxels
print(s1v1['zmask'].shape)
print(s1v1['zmask'].nonzero())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'zmask', 'X'])
# (360, 948)
# (98, 98, 30)
# (array([37, 37, 37, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 39, 39, 39, 39,
#        39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 40, 40, 40, 40, 40, 40,
#        40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40,
#        41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41,
#        41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41,
#        41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 42, 42,
#        42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42,
#        42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42,
#        42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42,
#        42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 43, 43, 43, 43, 43,
#        43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43,
# ...
